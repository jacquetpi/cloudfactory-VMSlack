# %%
import pandas as pd
import os.path
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_ref = pd.read_csv('results-latency/results-20230714-nopin')
dataset_v1 = pd.read_csv('results-latency/results-20230825-oc3-activecores')
dataset_v2 = pd.read_csv('results-latency/results-20230901-oc3-activecores2')

# %%
dataset.head()

# %%
dataset = dataset_ref.loc[dataset_ref['90th'] <= 100]

g = sns.scatterplot(data=dataset, x='timestamp', y='50th', hue='vm')
g.get_legend().remove()
#g = sns.jointplot(data=dataset_ref, x='timestamp', y='90th', kind="hex", color="#4CB391")

# %%
dataset = dataset_v1.loc[dataset_v1['90th'] <= 100]

g = sns.scatterplot(data=dataset, x='timestamp', y='50th', hue='vm')
g.get_legend().remove()
#g = sns.jointplot(data=dataset_ref, x='timestamp', y='90th', kind="hex", color="#4CB391")

# %%
dataset = dataset_v2.loc[dataset_v2['90th'] <= 100]

g = sns.scatterplot(data=dataset, x='timestamp', y='50th', hue='vm')
g.get_legend().remove()
#g = sns.jointplot(data=dataset_ref, x='timestamp', y='90th', kind="hex", color="#4CB391")

# %%
dataset_v3 = pd.read_csv('results-latency/results-20230907-activecores3')

# %%
dataset = dataset_v3.loc[dataset_v3['90th'] <= 100]

g = sns.scatterplot(data=dataset, x='timestamp', y='50th', hue='vm')
g.get_legend().remove()
